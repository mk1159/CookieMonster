# %%
import os, random, shutil

def randomize_datasets(pvTrain, pvTest, pvValid, path, typeML):
    
    totalFiles = len(next(os.walk(path+typeML))[2])
    trainMove = 0
    testMove = 0
    validMove = 0
    
    
    # n%20 < 16 put in folder train
    # elif x%20 < 19 put in folder test
    # else (x%20 == 19) put in folder verify
    
    print ("Moving {0} files...".format(totalFiles))
    x = 0
    while (x!=totalFiles):
        random.seed();
        for root, dirs, files in os.walk(path+typeML):
            for name in files:
                chance = random.uniform(0,99)
                rfile=os.path.join(root, name)    

                if (chance % 100 < pvValid):
                    shutil.move(rfile, path+'/valid/'+typeML+'/')
                    validMove = validMove + 1
                elif (chance % 100 < pvValid + pvTest):
                    shutil.move(rfile, path+'/test/'+typeML+'/')
                    testMove = testMove + 1
                else:
                    shutil.move(rfile, path+'/train/'+typeML+'/')
                    trainMove = trainMove + 1
                x = x + 1
        
    print ("Moved {0} to train!".format(trainMove))
    print ("Moved {0} to test!".format(testMove))
    print ("Moved {0} to valid!".format(validMove))
 


    
randomize_datasets(80, 15, 5, '/home/aashinshazar/beta/cookiesinthejar/', 'bad')
randomize_datasets(80, 15, 5, '/home/aashinshazar/beta/cookiesinthejar/', 'good')
# Out:
# Moving 326 files...
# Moved 251 to train!
# Moved 63 to test!
# Moved 12 to valid!
# Moving 253 files...
# Moved 199 to train!
# Moved 37 to test!
# Moved 17 to valid!

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

bigPath = '/home/aashinshazar/beta/cookiesinthejar/'

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    part_files = np.array(data['filenames'])
    part_targets = np_utils.to_categorical(np.array(data['target']), 2)
    return part_files, part_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset(bigPath + 'train')
test_files, test_targets = load_dataset(bigPath +'test')
valid_files, valid_targets = load_dataset(bigPath +'valid')

print('There are %d training part images.' % len(train_files))
print('There are %d validation part images.' % len(valid_files))
print('There are %d test part images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 1440 training part images.
# There are 77 validation part images.
# There are 275 test part images.

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 1440/1440 [00:07<00:00, 185.91it/s]
# 100%|██████████| 77/77 [00:00<00:00, 185.57it/s]
# 100%|██████████| 275/275 [00:01<00:00, 206.24it/s]

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.utils import multi_gpu_model
import tensorflow as tf

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 3)))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=2))
model.add(GlobalAveragePooling2D())
model.add(Dense(2, activation='sigmoid'))

model.summary()

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224, 224, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 112, 112, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 56, 56, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        16448
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 27,122
# Trainable params: 27,122
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
import time

import matplotlib.pyplot as plt
import numpy

epochs = 100
batch_size=20

bestModelSavedName = "finalBench.hdf5"

checkpointer = ModelCheckpoint(filepath=bestModelSavedName, 
                               verbose=1, save_best_only=True)

history = model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets), 
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer], verbose=2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1440 samples, validate on 77 samples
# Epoch 1/100
#  - 4s - loss: 0.6806 - acc: 0.5958 - val_loss: 0.6846 - val_acc: 0.5844
#
# Epoch 00001: val_loss improved from inf to 0.68463, saving model to finalBench.hdf5
# Epoch 2/100
#  - 2s - loss: 0.6617 - acc: 0.6059 - val_loss: 0.6814 - val_acc: 0.5844
#
# Epoch 00002: val_loss improved from 0.68463 to 0.68144, saving model to finalBench.hdf5
# Epoch 3/100
#  - 2s - loss: 0.6562 - acc: 0.6260 - val_loss: 0.6789 - val_acc: 0.5844
#
# Epoch 00003: val_loss improved from 0.68144 to 0.67892, saving model to finalBench.hdf5
# Epoch 4/100
#  - 2s - loss: 0.6443 - acc: 0.6354 - val_loss: 0.6816 - val_acc: 0.6299
#
# Epoch 00004: val_loss did not improve from 0.67892
# Epoch 5/100
#  - 2s - loss: 0.6385 - acc: 0.6573 - val_loss: 0.6740 - val_acc: 0.5974
#
# Epoch 00005: val_loss improved from 0.67892 to 0.67401, saving model to finalBench.hdf5
# Epoch 6/100
#  - 2s - loss: 0.6223 - acc: 0.6670 - val_loss: 0.6691 - val_acc: 0.5974
#
# Epoch 00006: val_loss improved from 0.67401 to 0.66908, saving model to finalBench.hdf5
# Epoch 7/100
#  - 2s - loss: 0.6156 - acc: 0.6708 - val_loss: 0.6664 - val_acc: 0.5844
#
# Epoch 00007: val_loss improved from 0.66908 to 0.66641, saving model to finalBench.hdf5
# Epoch 8/100
#  - 2s - loss: 0.6088 - acc: 0.6837 - val_loss: 0.6684 - val_acc: 0.6039
#
# Epoch 00008: val_loss did not improve from 0.66641
# Epoch 9/100
#  - 2s - loss: 0.6074 - acc: 0.6868 - val_loss: 0.6662 - val_acc: 0.5779
#
# Epoch 00009: val_loss improved from 0.66641 to 0.66622, saving model to finalBench.hdf5
# Epoch 10/100
#  - 2s - loss: 0.6050 - acc: 0.6906 - val_loss: 0.6703 - val_acc: 0.6364
#
# Epoch 00010: val_loss did not improve from 0.66622
# Epoch 11/100
#  - 2s - loss: 0.5987 - acc: 0.6882 - val_loss: 0.6663 - val_acc: 0.6104
#
# Epoch 00011: val_loss did not improve from 0.66622
# Epoch 12/100
#  - 2s - loss: 0.5974 - acc: 0.7017 - val_loss: 0.6670 - val_acc: 0.6299
#
# Epoch 00012: val_loss did not improve from 0.66622
# Epoch 13/100
#  - 2s - loss: 0.5912 - acc: 0.7045 - val_loss: 0.6655 - val_acc: 0.6558
#
# Epoch 00013: val_loss improved from 0.66622 to 0.66548, saving model to finalBench.hdf5
# Epoch 14/100
#  - 2s - loss: 0.5902 - acc: 0.7062 - val_loss: 0.6703 - val_acc: 0.6818
#
# Epoch 00014: val_loss did not improve from 0.66548
# Epoch 15/100
#  - 2s - loss: 0.5857 - acc: 0.7149 - val_loss: 0.6615 - val_acc: 0.6234
#
# Epoch 00015: val_loss improved from 0.66548 to 0.66146, saving model to finalBench.hdf5
# Epoch 16/100
#  - 2s - loss: 0.5855 - acc: 0.7063 - val_loss: 0.6608 - val_acc: 0.6364
#
# Epoch 00016: val_loss improved from 0.66146 to 0.66082, saving model to finalBench.hdf5
# Epoch 17/100
#  - 2s - loss: 0.5863 - acc: 0.7010 - val_loss: 0.6645 - val_acc: 0.6494
#
# Epoch 00017: val_loss did not improve from 0.66082
# Epoch 18/100
#  - 2s - loss: 0.5865 - acc: 0.7101 - val_loss: 0.6684 - val_acc: 0.7013
#
# Epoch 00018: val_loss did not improve from 0.66082
# Epoch 19/100
#  - 2s - loss: 0.5785 - acc: 0.7139 - val_loss: 0.6692 - val_acc: 0.7143
#
# Epoch 00019: val_loss did not improve from 0.66082
# Epoch 20/100
#  - 2s - loss: 0.5779 - acc: 0.7198 - val_loss: 0.6751 - val_acc: 0.5584
#
# Epoch 00020: val_loss did not improve from 0.66082
# Epoch 21/100
#  - 2s - loss: 0.5703 - acc: 0.7208 - val_loss: 0.6745 - val_acc: 0.5455
#
# Epoch 00021: val_loss did not improve from 0.66082
# Epoch 22/100
#  - 2s - loss: 0.5750 - acc: 0.7215 - val_loss: 0.6664 - val_acc: 0.6883
#
# Epoch 00022: val_loss did not improve from 0.66082
# Epoch 23/100
#  - 2s - loss: 0.5690 - acc: 0.7326 - val_loss: 0.6621 - val_acc: 0.7338
#
# Epoch 00023: val_loss did not improve from 0.66082
# Epoch 24/100
#  - 2s - loss: 0.5680 - acc: 0.7267 - val_loss: 0.6760 - val_acc: 0.5065
#
# Epoch 00024: val_loss did not improve from 0.66082
# Epoch 25/100
#  - 2s - loss: 0.5627 - acc: 0.7413 - val_loss: 0.6646 - val_acc: 0.6234
#
# Epoch 00025: val_loss did not improve from 0.66082
# Epoch 26/100
#  - 2s - loss: 0.5702 - acc: 0.7170 - val_loss: 0.6774 - val_acc: 0.5260
#
# Epoch 00026: val_loss did not improve from 0.66082
# Epoch 27/100
#  - 2s - loss: 0.5681 - acc: 0.7194 - val_loss: 0.6770 - val_acc: 0.5390
#
# Epoch 00027: val_loss did not improve from 0.66082
# Epoch 28/100
#  - 2s - loss: 0.5564 - acc: 0.7368 - val_loss: 0.6665 - val_acc: 0.6429
#
# Epoch 00028: val_loss did not improve from 0.66082
# Epoch 29/100
#  - 2s - loss: 0.5618 - acc: 0.7260 - val_loss: 0.6692 - val_acc: 0.5714
#
# Epoch 00029: val_loss did not improve from 0.66082
# Epoch 30/100
#  - 2s - loss: 0.5575 - acc: 0.7368 - val_loss: 0.6739 - val_acc: 0.5390
#
# Epoch 00030: val_loss did not improve from 0.66082
# Epoch 31/100
#  - 2s - loss: 0.5517 - acc: 0.7406 - val_loss: 0.6582 - val_acc: 0.6429
#
# Epoch 00031: val_loss improved from 0.66082 to 0.65819, saving model to finalBench.hdf5
# Epoch 32/100
#  - 2s - loss: 0.5554 - acc: 0.7344 - val_loss: 0.6641 - val_acc: 0.6429
#
# Epoch 00032: val_loss did not improve from 0.65819
# Epoch 33/100
#  - 2s - loss: 0.5551 - acc: 0.7399 - val_loss: 0.6654 - val_acc: 0.6234
#
# Epoch 00033: val_loss did not improve from 0.65819
# Epoch 34/100
#  - 2s - loss: 0.5552 - acc: 0.7392 - val_loss: 0.6713 - val_acc: 0.5325
#
# Epoch 00034: val_loss did not improve from 0.65819
# Epoch 35/100
#  - 2s - loss: 0.5532 - acc: 0.7326 - val_loss: 0.6759 - val_acc: 0.5130
#
# Epoch 00035: val_loss did not improve from 0.65819
# Epoch 36/100
#  - 2s - loss: 0.5455 - acc: 0.7437 - val_loss: 0.6809 - val_acc: 0.5065
#
# Epoch 00036: val_loss did not improve from 0.65819
# Epoch 37/100
#  - 2s - loss: 0.5398 - acc: 0.7472 - val_loss: 0.6754 - val_acc: 0.5390
#
# Epoch 00037: val_loss did not improve from 0.65819
# Epoch 38/100
#  - 2s - loss: 0.5516 - acc: 0.7431 - val_loss: 0.6739 - val_acc: 0.5584
#
# Epoch 00038: val_loss did not improve from 0.65819
# Epoch 39/100
#  - 2s - loss: 0.5524 - acc: 0.7420 - val_loss: 0.6851 - val_acc: 0.5260
#
# Epoch 00039: val_loss did not improve from 0.65819
# Epoch 40/100
#  - 2s - loss: 0.5374 - acc: 0.7531 - val_loss: 0.6830 - val_acc: 0.4935
#
# Epoch 00040: val_loss did not improve from 0.65819
# Epoch 41/100
#  - 2s - loss: 0.5377 - acc: 0.7500 - val_loss: 0.6620 - val_acc: 0.6039
#
# Epoch 00041: val_loss did not improve from 0.65819
# Epoch 42/100
#  - 2s - loss: 0.5376 - acc: 0.7486 - val_loss: 0.6826 - val_acc: 0.5000
#
# Epoch 00042: val_loss did not improve from 0.65819
# Epoch 43/100
#  - 2s - loss: 0.5373 - acc: 0.7462 - val_loss: 0.6773 - val_acc: 0.5455
#
# Epoch 00043: val_loss did not improve from 0.65819
# Epoch 44/100
#  - 2s - loss: 0.5333 - acc: 0.7497 - val_loss: 0.6858 - val_acc: 0.5130
#
# Epoch 00044: val_loss did not improve from 0.65819
# Epoch 45/100
#  - 2s - loss: 0.5331 - acc: 0.7490 - val_loss: 0.6776 - val_acc: 0.5260
#
# Epoch 00045: val_loss did not improve from 0.65819
# Epoch 46/100
#  - 2s - loss: 0.5277 - acc: 0.7559 - val_loss: 0.6858 - val_acc: 0.5195
#
# Epoch 00046: val_loss did not improve from 0.65819
# Epoch 47/100
#  - 2s - loss: 0.5276 - acc: 0.7649 - val_loss: 0.6644 - val_acc: 0.5909
#
# Epoch 00047: val_loss did not improve from 0.65819
# Epoch 48/100
#  - 2s - loss: 0.5256 - acc: 0.7566 - val_loss: 0.6751 - val_acc: 0.5260
#
# Epoch 00048: val_loss did not improve from 0.65819
# Epoch 49/100
#  - 2s - loss: 0.5293 - acc: 0.7677 - val_loss: 0.6756 - val_acc: 0.5325
#
# Epoch 00049: val_loss did not improve from 0.65819
# Epoch 50/100
#  - 2s - loss: 0.5225 - acc: 0.7656 - val_loss: 0.6855 - val_acc: 0.5260
#
# Epoch 00050: val_loss did not improve from 0.65819
# Epoch 51/100
#  - 2s - loss: 0.5285 - acc: 0.7566 - val_loss: 0.6815 - val_acc: 0.5065
#
# Epoch 00051: val_loss did not improve from 0.65819
# Epoch 52/100
#  - 2s - loss: 0.5211 - acc: 0.7604 - val_loss: 0.6671 - val_acc: 0.5779
#
# Epoch 00052: val_loss did not improve from 0.65819
# Epoch 53/100
#  - 2s - loss: 0.5271 - acc: 0.7552 - val_loss: 0.6797 - val_acc: 0.5519
#
# Epoch 00053: val_loss did not improve from 0.65819
# Epoch 54/100
#  - 2s - loss: 0.5156 - acc: 0.7524 - val_loss: 0.6735 - val_acc: 0.5649
#
# Epoch 00054: val_loss did not improve from 0.65819
# Epoch 55/100
#  - 2s - loss: 0.5227 - acc: 0.7500 - val_loss: 0.6725 - val_acc: 0.5649
#
# Epoch 00055: val_loss did not improve from 0.65819
# Epoch 56/100
#  - 2s - loss: 0.5182 - acc: 0.7639 - val_loss: 0.6687 - val_acc: 0.5974
#
# Epoch 00056: val_loss did not improve from 0.65819
# Epoch 57/100
#  - 2s - loss: 0.5168 - acc: 0.7514 - val_loss: 0.6674 - val_acc: 0.5779
#
# Epoch 00057: val_loss did not improve from 0.65819
# Epoch 58/100
#  - 2s - loss: 0.5155 - acc: 0.7628 - val_loss: 0.6903 - val_acc: 0.5195
#
# Epoch 00058: val_loss did not improve from 0.65819
# Epoch 59/100
#  - 2s - loss: 0.5211 - acc: 0.7615 - val_loss: 0.6782 - val_acc: 0.5519
#
# Epoch 00059: val_loss did not improve from 0.65819
# Epoch 60/100
#  - 2s - loss: 0.5088 - acc: 0.7649 - val_loss: 0.6838 - val_acc: 0.5325
#
# Epoch 00060: val_loss did not improve from 0.65819
# Epoch 61/100
#  - 2s - loss: 0.5127 - acc: 0.7663 - val_loss: 0.6775 - val_acc: 0.5325
#
# Epoch 00061: val_loss did not improve from 0.65819
# Epoch 62/100
#  - 2s - loss: 0.5088 - acc: 0.7625 - val_loss: 0.6859 - val_acc: 0.5714
#
# Epoch 00062: val_loss did not improve from 0.65819
# Epoch 63/100
#  - 2s - loss: 0.5044 - acc: 0.7635 - val_loss: 0.6900 - val_acc: 0.5065
#
# Epoch 00063: val_loss did not improve from 0.65819
# Epoch 64/100
#  - 2s - loss: 0.5052 - acc: 0.7663 - val_loss: 0.6802 - val_acc: 0.5584
#
# Epoch 00064: val_loss did not improve from 0.65819
# Epoch 65/100
#  - 2s - loss: 0.5149 - acc: 0.7597 - val_loss: 0.6923 - val_acc: 0.5260
#
# Epoch 00065: val_loss did not improve from 0.65819
# Epoch 66/100
#  - 2s - loss: 0.5103 - acc: 0.7660 - val_loss: 0.6787 - val_acc: 0.5455
#
# Epoch 00066: val_loss did not improve from 0.65819
# Epoch 67/100
#  - 2s - loss: 0.5045 - acc: 0.7722 - val_loss: 0.6885 - val_acc: 0.5130
#
# Epoch 00067: val_loss did not improve from 0.65819
# Epoch 68/100
#  - 2s - loss: 0.5024 - acc: 0.7653 - val_loss: 0.6908 - val_acc: 0.5000
#
# Epoch 00068: val_loss did not improve from 0.65819
# Epoch 69/100
#  - 2s - loss: 0.5004 - acc: 0.7712 - val_loss: 0.6843 - val_acc: 0.5325
#
# Epoch 00069: val_loss did not improve from 0.65819
# Epoch 70/100
#  - 2s - loss: 0.4981 - acc: 0.7674 - val_loss: 0.6529 - val_acc: 0.6234
#
# Epoch 00070: val_loss improved from 0.65819 to 0.65295, saving model to finalBench.hdf5
# Epoch 71/100
#  - 2s - loss: 0.5013 - acc: 0.7656 - val_loss: 0.6722 - val_acc: 0.5649
#
# Epoch 00071: val_loss did not improve from 0.65295
# Epoch 72/100
#  - 2s - loss: 0.5014 - acc: 0.7538 - val_loss: 0.6752 - val_acc: 0.5455
#
# Epoch 00072: val_loss did not improve from 0.65295
# Epoch 73/100
#  - 2s - loss: 0.4977 - acc: 0.7854 - val_loss: 0.6686 - val_acc: 0.5455
#
# Epoch 00073: val_loss did not improve from 0.65295
# Epoch 74/100
#  - 2s - loss: 0.4965 - acc: 0.7715 - val_loss: 0.6712 - val_acc: 0.5519
#
# Epoch 00074: val_loss did not improve from 0.65295
# Epoch 75/100
#  - 2s - loss: 0.4966 - acc: 0.7747 - val_loss: 0.6662 - val_acc: 0.5909
#
# Epoch 00075: val_loss did not improve from 0.65295
# Epoch 76/100
#  - 2s - loss: 0.4865 - acc: 0.7701 - val_loss: 0.7102 - val_acc: 0.4545
#
# Epoch 00076: val_loss did not improve from 0.65295
# Epoch 77/100
#  - 2s - loss: 0.4955 - acc: 0.7618 - val_loss: 0.6591 - val_acc: 0.6104
#
# Epoch 00077: val_loss did not improve from 0.65295
# Epoch 78/100
#  - 2s - loss: 0.4979 - acc: 0.7632 - val_loss: 0.6861 - val_acc: 0.5325
#
# Epoch 00078: val_loss did not improve from 0.65295
# Epoch 79/100
#  - 2s - loss: 0.4875 - acc: 0.7743 - val_loss: 0.6946 - val_acc: 0.5065
#
# Epoch 00079: val_loss did not improve from 0.65295
# Epoch 80/100
#  - 2s - loss: 0.4867 - acc: 0.7691 - val_loss: 0.6774 - val_acc: 0.5390
#
# Epoch 00080: val_loss did not improve from 0.65295
# Epoch 81/100
#  - 2s - loss: 0.4885 - acc: 0.7778 - val_loss: 0.7105 - val_acc: 0.4675
#
# Epoch 00081: val_loss did not improve from 0.65295
# Epoch 82/100
#  - 2s - loss: 0.4851 - acc: 0.7826 - val_loss: 0.6949 - val_acc: 0.5065
#
# Epoch 00082: val_loss did not improve from 0.65295
# Epoch 83/100
#  - 2s - loss: 0.4823 - acc: 0.7733 - val_loss: 0.6912 - val_acc: 0.4935
#
# Epoch 00083: val_loss did not improve from 0.65295
# Epoch 84/100
#  - 2s - loss: 0.4756 - acc: 0.7924 - val_loss: 0.6909 - val_acc: 0.5000
#
# Epoch 00084: val_loss did not improve from 0.65295
# Epoch 85/100
#  - 2s - loss: 0.4751 - acc: 0.7816 - val_loss: 0.6769 - val_acc: 0.5519
#
# Epoch 00085: val_loss did not improve from 0.65295
# Epoch 86/100
#  - 2s - loss: 0.4814 - acc: 0.7691 - val_loss: 0.6637 - val_acc: 0.5974
#
# Epoch 00086: val_loss did not improve from 0.65295
# Epoch 87/100
#  - 2s - loss: 0.4857 - acc: 0.7792 - val_loss: 0.6987 - val_acc: 0.4935
#
# Epoch 00087: val_loss did not improve from 0.65295
# Epoch 88/100
#  - 2s - loss: 0.4776 - acc: 0.7747 - val_loss: 0.6914 - val_acc: 0.5130
#
# Epoch 00088: val_loss did not improve from 0.65295
# Epoch 89/100
#  - 2s - loss: 0.4793 - acc: 0.7760 - val_loss: 0.6594 - val_acc: 0.5844
#
# Epoch 00089: val_loss did not improve from 0.65295
# Epoch 90/100
#  - 2s - loss: 0.4796 - acc: 0.7910 - val_loss: 0.6774 - val_acc: 0.5195
#
# Epoch 00090: val_loss did not improve from 0.65295
# Epoch 91/100
#  - 2s - loss: 0.4716 - acc: 0.7830 - val_loss: 0.6746 - val_acc: 0.5390
#
# Epoch 00091: val_loss did not improve from 0.65295
# Epoch 92/100
#  - 2s - loss: 0.4773 - acc: 0.7715 - val_loss: 0.7164 - val_acc: 0.4545
#
# Epoch 00092: val_loss did not improve from 0.65295
# Epoch 93/100
#  - 2s - loss: 0.4714 - acc: 0.7830 - val_loss: 0.6849 - val_acc: 0.5195
#
# Epoch 00093: val_loss did not improve from 0.65295
# Epoch 94/100
#  - 2s - loss: 0.4723 - acc: 0.7854 - val_loss: 0.7169 - val_acc: 0.4545
#
# Epoch 00094: val_loss did not improve from 0.65295
# Epoch 95/100
#  - 2s - loss: 0.4842 - acc: 0.7750 - val_loss: 0.7071 - val_acc: 0.4805
#
# Epoch 00095: val_loss did not improve from 0.65295
# Epoch 96/100
#  - 2s - loss: 0.4679 - acc: 0.7816 - val_loss: 0.6762 - val_acc: 0.5714
#
# Epoch 00096: val_loss did not improve from 0.65295
# Epoch 97/100
#  - 2s - loss: 0.4708 - acc: 0.7903 - val_loss: 0.7088 - val_acc: 0.4545
#
# Epoch 00097: val_loss did not improve from 0.65295
# Epoch 98/100
#  - 2s - loss: 0.4597 - acc: 0.7823 - val_loss: 0.6986 - val_acc: 0.4935
#
# Epoch 00098: val_loss did not improve from 0.65295
# Epoch 99/100
#  - 2s - loss: 0.4656 - acc: 0.7889 - val_loss: 0.7009 - val_acc: 0.4805
#
# Epoch 00099: val_loss did not improve from 0.65295
# Epoch 100/100
#  - 2s - loss: 0.4627 - acc: 0.7882 - val_loss: 0.6578 - val_acc: 0.5974
#
# Epoch 00100: val_loss did not improve from 0.65295

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import f1_score
import pandas as pd

model.load_weights('/home/aashinshazar/' + bestModelSavedName)

# get index of predicted part for each image in the test image set
part_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(part_predictions)==np.argmax(test_targets, axis=1))/len(part_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)

print ("Fscore:", f1_score(np.argmax(test_targets, axis=1), part_predictions, average=None) )

y_actu = pd.Series(np.argmax(test_targets, axis=1), name='Actual')
y_pred = pd.Series(part_predictions, name='Predicted')

df_confusion = pd.crosstab(y_actu, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
print (df_confusion)
# Out:
# Test accuracy: 62.1818%
# Fscore: [0.60902256 0.63380282]
# Predicted    0    1  All
# Actual
# 0           81   24  105
# 1           80   90  170
# All        161  114  275
